# %%
# !gdown --id 1NlyCS-fuTsupwHDcYx0ecpnsTAi5Ls6V
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1NlyCS-fuTsupwHDcYx0ecpnsTAi5Ls6V
# To: /content/Real_estate.csv
# 100% 22.0k/22.0k [00:00<00:00, 50.5MB/s]

# %%
import numpy as np
import math as m
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Load data
data = np.genfromtxt('Real_estate.csv', delimiter=',')
data = data[1:] # xóa header
data = data[:, 1:]
print(data.shape)

X = data[:, :-1]
y = data[:, -1]
print(X.size)
# Out:
# (414, 7)
# 2484

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
data_train = np.append(X_train, np.expand_dims(y_train, axis=1), axis=1)

# %%
#transaction date - price correlation graph
trans_date = X_train[:, 0]
price = y_train


plt.scatter(trans_date, price)
plt.grid()

plt.xlabel("trans_date")
plt.ylabel("price")

slope, intercept = np.polyfit(trans_date, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(trans_date), max(trans_date), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
#house age - price graph
age = X_train[:, 1]
price = y_train


plt.scatter(age, price)
plt.grid()

plt.xlabel("house age")
plt.ylabel("price")

slope, intercept = np.polyfit(age, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(age), max(age), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
#distance - price graph
distance = X_train[:, 2]
price = y_train


plt.scatter(distance, price)
plt.grid()

plt.xlabel("distance")
plt.ylabel("price")

slope, intercept = np.polyfit(distance, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(distance), max(distance), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
#number of convenience store - price graph

no_of_store = X_train[:, 3]
price = y_train


plt.scatter(no_of_store, price)
plt.grid()

plt.xlabel("no_of_store")
plt.ylabel("price")

slope, intercept = np.polyfit(no_of_store, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(no_of_store), max(no_of_store), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
#latitude - price graph
latitude = X_train[:, 4]
price = y_train


plt.scatter(latitude, price)
plt.grid()

plt.xlabel("latitude")
plt.ylabel("price")

slope, intercept = np.polyfit(latitude, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(latitude), max(latitude), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
#longitude - price
longitude = X_train[:, 5]
price = y_train


plt.scatter(longitude, price)
plt.grid()

plt.xlabel("longitude")
plt.ylabel("price")

slope, intercept = np.polyfit(longitude, price, 1)

def yfit(x):
    return slope*x + intercept

xfit = np.linspace(min(longitude), max(longitude), 1000)
plt.plot(xfit, yfit(xfit), color = 'r')

# %%
df = pd.DataFrame(data_train)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Add labels and title
plt.title('Correlation Matrix')
plt.xlabel('Columns')
plt.ylabel('Columns')

# Display the heatmap
plt.show()

# %% [markdown]
# We can see that only feature 3, 4, 5 have positive correlation with feature 6(housing price) so we will only train with these features. We will train with library functions like exercise 1
